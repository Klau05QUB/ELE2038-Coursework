# %%
#Installing necessary libraries

# %pip install control > NUL
# %pip install matplotlib > NUL
# %pip install numpy > NUL

# %%
import control as ctrl
from math import exp, sqrt, sin
import matplotlib.pyplot as plt
import numpy as np

s = ctrl.TransferFunction.s

m = 0.462
g = 9.81
d = 0.42
delta = 0.65
r = 0.123
R = 2200
L0 = 0.125
L1 = 0.0241
alpha = 1.2
c_val = 6.811
k = 1885
b = 10.4
tau = 0.03
phi = np.deg2rad(41)

x_2e = 0

Kp = 700
Kd = 20
Ki = 400

# %% [markdown]
# Adjusting x_1e as the set point in range (0.47m-0.53m)

# %%
x_1e = 0.47

while x_1e<=0.53:

  x_3e = (delta - x_1e)*sqrt( (k*(x_1e-d) - m*g*sin(phi)) / c_val)

  a_3 = (5/(7*m)) * (2*c_val*x_3e)/((delta - x_1e)**2) #x3
  a_2 = (5/(7*m))*(-b) #x2
  a_1 = (5/(7*m)) * ( (2*c_val*(x_3e**2) ) / ( (delta - x_1e)**3 )  -k) #x1

  b_1 = 1/ (L0 + L1*exp(-alpha*(delta - x_1e)))
  b_2 = -R/ (L0 + L1*exp(-alpha*(delta - x_1e)))

  Gm = a_3/(s**2 - a_2*s - a_1)
  Ge = b_1/(s - b_2)
  Gs = (1)/((tau*s)+1)

  Gme = Gm*Ge

  if x_1e == 0.47 or x_1e == 0.48 or x_1e == 0.49:
    timepts = np.linspace(0, 100, 1000)

  for Gain_scaling_factor in [n for n in np.linspace(1,10,10)]:

    Gc = Gain_scaling_factor * (Kp + Ki/s + Kd*s)
    G_closed_loop = ctrl.feedback(Gme*Gc, Gs)

    poles = ctrl.poles(G_closed_loop)


    #Only plot the responses if the system is stable (all poles have negative real parts)
    if all(pole.real < 0 for pole in poles):
    #Impulse response

      time,xs = ctrl.impulse_response(G_closed_loop, timepts=timepts)
      xs_scaled = xs*0.01
      plt.plot(time, xs_scaled)
      plt.title(f"Impulse response at Kp: {Kp * Gain_scaling_factor}, Kd: {Kd * Gain_scaling_factor}, Ki: {Ki * Gain_scaling_factor}, Gain scaling factor: {Gain_scaling_factor}")
      plt.xlabel("Time/s")
      plt.ylabel(f"Position from setpoint x={x_1e} /m")
      plt.show()

      impulse_response_max_value = max(xs_scaled)
      impulse_response_min_value = min(xs_scaled)
      impulse_response_max_overshoot = abs(impulse_response_min_value )

      print(f"Max: {impulse_response_max_value:.3f} m \nMin: {impulse_response_min_value:.3f} m")
      print(f"Maximum overshoot: {(impulse_response_max_overshoot / x_1e)*100:.3f}%")


      #step response

      time,xs = ctrl.step_response(G_closed_loop, timepts=timepts)
      xs_scaled = xs*0.01
      plt.plot(time, xs_scaled)
      plt.title(f"Step response at Kp: {Kp * Gain_scaling_factor}, Kd: {Kd * Gain_scaling_factor}, Ki: {Ki * Gain_scaling_factor}, Gain scaling factor: {Gain_scaling_factor}")
      plt.xlabel("Time/s")
      plt.ylabel(f"Position from setpoint x={x_1e} /m")
      plt.show()

      step_response_max_value = max(xs_scaled)
      step_response_min_value = min(xs_scaled)
      step_response_max_overshoot = max( abs(step_response_max_value) , abs(step_response_min_value) )

      print(f"Max: {step_response_max_value:.3f} m \nMin: {step_response_min_value:.3f} m")
      print(f"Maximum overshoot: {((step_response_max_overshoot -0.01) / x_1e)*100:.3f}%\n\n")

  x_1e = x_1e+0.01
# Out:
# Max: 0.008 m
# Min: -0.021 m
# Maximum overshoot: 4.444%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.010%
# Max: 0.012 m
# Min: -0.041 m
# Maximum overshoot: 8.692%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.009 m
# Min: -0.058 m
# Maximum overshoot: 12.309%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.017 m
# Min: -0.070 m
# Maximum overshoot: 14.978%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.023 m
# Min: -0.077 m
# Maximum overshoot: 16.484%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.024 m
# Min: -0.078 m
# Maximum overshoot: 16.695%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.018 m
# Min: -0.073 m
# Maximum overshoot: 15.554%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.018 m
# Min: -0.072 m
# Maximum overshoot: 15.299%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.017 m
# Min: -0.084 m
# Maximum overshoot: 17.917%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.012 m
# Min: -0.090 m
# Maximum overshoot: 19.171%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.010 m
# Min: -0.020 m
# Maximum overshoot: 4.119%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.024 m
# Min: -0.046 m
# Maximum overshoot: 9.687%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.035 m
# Min: -0.075 m
# Maximum overshoot: 15.531%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.036 m
# Min: -0.100 m
# Maximum overshoot: 20.770%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.025 m
# Min: -0.119 m
# Maximum overshoot: 24.771%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: 0.000%
# Max: 0.029 m
# Min: -0.130 m
# Maximum overshoot: 27.107%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: 0.000%
# Max: 0.039 m
# Min: -0.132 m
# Maximum overshoot: 27.528%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.038 m
# Min: -0.124 m
# Maximum overshoot: 25.928%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.025 m
# Min: -0.107 m
# Maximum overshoot: 22.315%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: 0.000%
# Max: 0.026 m
# Min: -0.111 m
# Maximum overshoot: 23.053%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.008 m
# Min: -0.012 m
# Maximum overshoot: 2.479%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.010 m
# Min: -0.019 m
# Maximum overshoot: 3.797%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: 0.000%
# Max: 0.023 m
# Min: -0.059 m
# Maximum overshoot: 11.997%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: 0.000%
# Max: 0.054 m
# Min: -0.104 m
# Maximum overshoot: 21.188%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.072 m
# Min: -0.146 m
# Maximum overshoot: 29.723%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.070 m
# Min: -0.179 m
# Maximum overshoot: 36.445%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.046 m
# Min: -0.199 m
# Maximum overshoot: 40.606%
# Max: 0.010 m
# Min: 0.000 m
# Maximum overshoot: -0.000%
# Max: 0.046 m
# Min: -0.205 m
# Maximum overshoot: 41.788%
# Max: 0.011 m
# Min: 0.000 m
# Maximum overshoot: 0.105%
# Max: 0.059 m
# Min: -0.195 m
# Maximum overshoot: 39.841%
# Max: 0.011 m
# Min: 0.000 m
# Maximum overshoot: 0.173%
# Max: 0.051 m
# Min: -0.171 m
# Maximum overshoot: 34.827%
# Max: 0.011 m
# Min: 0.000 m
# Maximum overshoot: 0.131%
# Max: 0.100 m
# Min: -0.022 m
# Maximum overshoot: 4.473%
# Max: 0.026 m
# Min: 0.000 m
# Maximum overshoot: 3.213%
# Max: 0.108 m
# Min: -0.032 m
# Maximum overshoot: 6.364%
# Max: 0.018 m
# Min: 0.000 m
# Maximum overshoot: 1.657%
# Max: 0.061 m
# Min: -0.070 m
# Maximum overshoot: 13.983%
# Max: 0.017 m
# Min: 0.000 m
# Maximum overshoot: 1.478%
# Max: 0.036 m
# Min: -0.046 m
# Maximum overshoot: 9.266%
# Max: 0.018 m
# Min: 0.000 m
# Maximum overshoot: 1.671%
# Max: 0.021 m
# Min: -0.099 m
# Maximum overshoot: 19.889%
# Max: 0.018 m
# Min: 0.000 m
# Maximum overshoot: 1.584%
# Max: 0.087 m
# Min: -0.178 m
# Maximum overshoot: 35.607%
# Max: 0.017 m
# Min: 0.000 m
# Maximum overshoot: 1.306%
# Max: 0.121 m
# Min: -0.241 m
# Maximum overshoot: 48.178%
# Max: 0.015 m
# Min: 0.000 m
# Maximum overshoot: 0.912%
# Max: 0.111 m
# Min: -0.282 m
# Maximum overshoot: 56.400%
# Max: 0.012 m
# Min: 0.000 m
# Maximum overshoot: 0.460%
# Max: 0.060 m
# Min: -0.298 m
# Maximum overshoot: 59.677%
# Max: 0.014 m
# Min: 0.000 m
# Maximum overshoot: 0.758%
# Max: 0.074 m
# Min: -0.289 m
# Maximum overshoot: 57.886%
# Max: 0.014 m
# Min: 0.000 m
# Maximum overshoot: 0.893%
# Max: 0.347 m
# Min: -0.179 m
# Maximum overshoot: 35.166%
# Max: 0.057 m
# Min: 0.000 m
# Maximum overshoot: 9.228%
# Max: 0.179 m
# Min: -0.176 m
# Maximum overshoot: 34.568%
# Max: 0.036 m
# Min: 0.000 m
# Maximum overshoot: 5.130%
# Max: 0.070 m
# Min: -0.135 m
# Maximum overshoot: 26.395%
# Max: 0.033 m
# Min: 0.000 m
# Maximum overshoot: 4.581%
# Max: 0.014 m
# Min: -0.158 m
# Maximum overshoot: 30.936%
# Max: 0.029 m
# Min: 0.000 m
# Maximum overshoot: 3.806%
# Max: 0.136 m
# Min: -0.285 m
# Maximum overshoot: 55.961%
# Max: 0.025 m
# Min: 0.000 m
# Maximum overshoot: 2.916%
# Max: 0.186 m
# Min: -0.372 m
# Maximum overshoot: 72.916%
# Max: 0.020 m
# Min: 0.000 m
# Maximum overshoot: 2.000%
# Max: 0.148 m
# Min: -0.414 m
# Maximum overshoot: 81.137%
# Max: 0.017 m
# Min: 0.000 m
# Maximum overshoot: 1.361%
# Max: 0.721 m
# Min: -0.811 m
# Maximum overshoot: 155.880%
# Max: 0.118 m
# Min: -0.076 m
# Maximum overshoot: 20.820%
# Max: 0.335 m
# Min: -0.364 m
# Maximum overshoot: 70.052%
# Max: 0.060 m
# Min: 0.000 m
# Maximum overshoot: 9.687%
# Max: 0.126 m
# Min: -0.263 m
# Maximum overshoot: 50.497%
# Max: 0.051 m
# Min: 0.000 m
# Maximum overshoot: 7.918%
# Max: 0.022 m
# Min: -0.268 m
# Maximum overshoot: 51.564%
# Max: 0.042 m
# Min: 0.000 m
# Maximum overshoot: 6.100%
# Max: 0.226 m
# Min: -0.451 m
# Maximum overshoot: 86.684%
# Max: 0.033 m
# Min: 0.000 m
# Maximum overshoot: 4.355%
# Max: 0.459 m
# Min: -0.702 m
# Maximum overshoot: 132.487%
# Max: 0.088 m
# Min: 0.000 m
# Maximum overshoot: 14.741%
# Max: 0.230 m
# Min: -0.377 m
# Maximum overshoot: 71.189%
# Max: 0.069 m
# Min: 0.000 m
# Maximum overshoot: 11.201%

# %% [markdown]
# Optimal gain scaling factors found per setpoint (balance between settling time and overshoot) :
#
#
# 0.47m = 7,
# 0.48m = 3,
# 0.49m = 3,
# 0.51m = 6,
# 0.52m = 10,
# 0.53m = 8.
#
# Overshoot is preferably < 20%, however for setpoints > 0.5m, this may not be possible with global gain scaling.
#
# Note that all of these gain scaling value choices are subjectively interpreted.
